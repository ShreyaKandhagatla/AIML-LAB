# %% [markdown]
# <a href="https://colab.research.google.com/github/ShreyaKandhagatla/AIML-LAB/blob/main/LAB2(AIML).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# DEPTH FIRST SEARCH![Screenshot (143).png](data:image/png;base64,...)

# %%
graph1 = {
    'A' : ['B','S'],
    'B' : ['A'],
    'C' : ['D','E','F','S'],
    'D' : ['C'],
    'E' : ['C','H'],
    'F' : ['C','G'],
    'G' : ['F','S'],
    'H' : ['E','G'],
    'S' : ['A','C','G']
}

def dfs(graph, node, visited):
    if node not in visited:
        visited.append(node)
        for k in graph[node]:
            dfs(graph,k, visited)
    return visited

visited = dfs(graph1,'D', [])
print(visited)
# Out:
# ['D', 'C', 'E', 'H', 'G', 'F', 'S', 'A', 'B']
